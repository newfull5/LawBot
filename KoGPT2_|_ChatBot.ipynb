# %% [markdown]
# <a href="https://colab.research.google.com/github/newfull5/LawBot/blob/master/KoGPT2_%7C_ChatBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
# !pip install torch==1.5.1+cu101 torchvision==0.6.1+cu101 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# !pip install mxnet gluonnlp sentencepiece pandas transformers pytorch_lightning

# %%
# !pip install git+https://github.com/SKT-AI/KoGPT2#egg=kogpt2

# %%
# !git clone --recurse-submodules https://github.com/haven-jeon/KoGPT2-chatbot.git

# %%
# %cd KoGPT2-chatbot
# Out:
# [Errno 2] No such file or directory: 'KoGPT2-chatbot'
# /content/KoGPT2-chatbot

# %%
# !CUDA_VISIBLE_DEVICES=0 python train_torch.py --train --gpus 1 --max_epochs 50
# Out:
# 2020-08-15 22:33:55.571122: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python train_torch.py --gpus 1 --chat
# Out:
# 2020-08-15 23:38:09.112882: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...
